# %% [markdown]
# # MSDS 430 Module 1 Python Assignment

# %% [markdown]
# #### In this assignment you will complete the following exercises and submit your notebook (ipynb file) to Canvas. Your file should include all output, i.e. run each cell and save your file before submitting.  In this course we will use only Python 3.0+

# %%
# Lines that start with 'hash' symbol are considered as comments and not executed.
# Run the code in this current cell. 
# The five lines of code define three variables: f, x1, x2, x3, x4 and x5.
# The first is a string, the next two are numerals (one an integer and the other a float point number),
# The third is a boolean value and the fourth the None object which represents "null" or "no value".
# Python defined variables are global and hence can be recalled later on in any other cell
f = 'first' # this is a string, assigned to f
x1 = 5      # this is an integer numeric value, assigned to x1
x2 = 4.3    # this is a numeric value, assigned x2
x3 = True   # this is a boolean value, assigned to x3
x4=0        # this is a zero value and not a null value, assigned to x4
x5=None     # this is a Null in python and has nothing defined in the named place of x5.
# All the above defined variables can be used later on in the Jupyter notebook
# If you want to check the data type of these you can use type(variable name)

# %% [markdown]
# **Problem 1 (1 pt.)**:
#
# Why doesn't the following print statement, print 'This is my first Python print execution' work?  Correct it in a new cell below it and run that cell to check your correction. Explain why the print statement wasn't working in your comment to your code in the new cell.

# %%
print 'This is my first Python print execution.'
# Out:
#   File "<ipython-input-5-c542cb438972>", line 1
#     print 'This is my first Python print execution.'
#                                                    ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('This is my first Python print execution.')?

# %%
print('This is my first Python print execution.')
#The Print  statement was not working intitially because there were no parentheses. 
#In Python, the Print statement is a function
# Out:
# This is my first Python print execution.

# %% [markdown]
# **Problem 2 (1 pts.)**:
#
# Execute the command below as is, and explain (in a comment) what the {} has achieved in the output. Then in the cell below it try the print statement again replacing "x2" by "x5". Here we are using the *format* method defined in the String class. We will have more to say about the String class and methods in general in the near future.
#
# For more details about powerful print options to play with see: https://realpython.com/python-f-strings/

# %%
print("This is my {}! print execution using format value stored in a variable, and it is {}!".format(f,x2))
#The {} is like a placeholder for whatever is in the variable x2. 
#When using format, the {} will be replaced for whatever is in x2 in this case 4.3.
# Out:
# This is my first! print execution using format value stored in a variable, and it is 4.3!

# %%
# Copy the code from the cell above here but replacing "x2" by "x5". How is the output different?
print("This is my {}! print execution using format value stored in a variable, and it is {}!".format(f,x5))
#The output is different because the x5=None in the first cell. So in this case the {} is replaced by None.
# Out:
# This is my first! print execution using format value stored in a variable, and it is None!

# %% [markdown]
# **Problem 3 (1 pts.)**:
#
# If you want to insert a cell below and move to that cell, what is the keyboard command? What is the keyboard command for executing the cell? Write your answers in the cell below. <br/>
# **Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**
#
# Note that all keyboard commands are decipherable by clicking on the keyboard icon below 'help'.

# %% [markdown]
# * Insert and Move to a Cell Below = Option/Alt + Enter;
# * Ctrl + Enter - Run/Execute a Cell

# %% [markdown]
# **Problem 4 (1 pts.)**:
#
# List the top five keyboard commands you think are useful to speed up your iPython notebook execution. Write your answers in the cell below. <br/>
# **Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**

# %% [markdown]
# * Shift+Enter -Run a Cell and Move to Next Cell
# * Alt + Enter - Insert a cell below and run current cell
# * Y - to code
# * M - to markdown
# * Enter - editing mode

# %% [markdown]
# **Problem 5 (1 pts.)**:
#
# Within an iPython notebook, how will you get help on any Python command? Write your answers in the cell below. <br/>
# **Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**

# %% [markdown]
# You can get help with any Python command by Shift + Tab for documentation about functions and just Tab to get help on autocompleting code

# %% [markdown]
# **Problem 6 (1 pts.)**:
#
# What are the top 5 magic commands that you feel are useful to interact with your operating system or Python execution? Write your answers in the cell below. <br/>
# **Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**

# %% [markdown]
# Top 5 magic commands are:
# * print() method to print to the terminal
# * saving information via assignment ex. x=y
# * Using for/while loop to iterate through a list or sequence
# * using f-string to write a sentence in python.
# * Can type Python 3 in terminal to execute code in the window.

# %% [markdown]
# There are several ways to insert a screenshot into a notebook. One default method is to use Edit --> Insert Image in a markdown cell. Other methods are provided in this short video: https://www.youtube.com/watch?v=xlD8FIM5biA

# %% [markdown]
# **Problem 7 (1 pts.)**:
#
# From the interactive interpreter (also called the terminal or command prompt on a Mac or command prompt on Windows) on your computer, find the product of any two numbers and take a screenshot. Insert your screenshot in the cell below. <br/>
# **Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**

# %% [markdown]
# ![PythonOperation.png](attachment:PythonOperation.png)

# %% [markdown]
# **Problem 8 (1 pts.)**:
#
# How do you get help about any command using "tab"? Write your answers in the cell below.
# **<br/> Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**

# %% [markdown]
# You can get help with any command using Tab by autocompletion of a statement in Python. When you type part of a line of code and hold down Tab you can access a drop down menu with list of code to choose from.

# %% [markdown]
# **Problem 9 (1 pts.)**:
#
# Open Anaconda Navigator on your computer and take a screenshot. Insert your screenshot in the cell below.<br/>
# **Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**

# %% [markdown]
# ![Screen%20Shot%202020-01-07%20at%209.44.31%20AM.png](attachment:Screen%20Shot%202020-01-07%20at%209.44.31%20AM.png)

# %% [markdown]
# **Problem 10 (1 pts.)**:
#
# From Anaconda, open Spyder. In the iPython console (lower right), find the sum of any two numbers. Take a screenshot and Insert your screenshot in the cell below. <br/>**Remember to change the cell type from 'Code' To 'Markdown' using the drop-down.**

# %% [markdown]
# ![Screen%20Shot%202020-01-07%20at%209.46.14%20AM.png](attachment:Screen%20Shot%202020-01-07%20at%209.46.14%20AM.png)
